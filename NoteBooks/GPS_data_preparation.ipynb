# %%
# Mount Google Drive
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
pip install aspose-cells
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 78.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.3/465.3 KB 34.9 MB/s eta 0:00:00
# ...
#   Created wheel for aspose-cells: filename=aspose_cells-23.3.0-py3-none-any.whl size=12298091 sha256=df14075624529a971237dc8291c16f78822db8e8f6434e1a7b0d03d0b074b35b
#   Stored in directory: /root/.cache/pip/wheels/22/fd/cb/5421c59383a52c6ec8df7a82b3a6fde9ced0764b44c0435d91
# Successfully built aspose-cells
# ...

# %%
import os
import csv
import numpy as np
import pandas as pd
import sys

# %%
# Data Path
root_dir = "gdrive/My Drive/Master_Thesis/"
train_dir = os.path.join(root_dir, 'data/Custom/CONAN_train.csv')
data = os.path.join(root_dir, 'data/Custom/hate_counter_tags.csv')
path = os.path.join(root_dir, 'CONAN_for_VAE.csv')
path_ = os.path.join(root_dir, 'CONAN_for_VAE.txt')

# %%
# Read csv file into dataframe
df = pd.read_csv(train_dir)
df = df["Counter_Speech"]

# %%
df.to_csv(path, header=None, index=None)

# %%
import  jpype     
import  asposecells     
jpype.startJVM() 
from asposecells.api import Workbook
  
# load CSV file
workbook = Workbook(path);
  
# save as TXT
workbook.save(path_);
  
jpype.shutdownJVM()
