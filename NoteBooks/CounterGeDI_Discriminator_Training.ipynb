# %%
# %env PYTHONPATH = # /env/python
# Out:
# env: PYTHONPATH=# /env/python

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-py38_4.12.0-Linux-x86_64.sh
# !chmod +x Miniconda3-py38_4.12.0-Linux-x86_64.sh
# !./Miniconda3-py38_4.12.0-Linux-x86_64.sh -b -f -p /usr/local
# !conda update conda
# Out:
# --2023-05-08 22:37:44--  https://repo.anaconda.com/miniconda/Miniconda3-py38_4.12.0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 76120962 (73M) [application/x-sh]
# Saving to: ‘Miniconda3-py38_4.12.0-Linux-x86_64.sh’
#
# Miniconda3-py38_4.1 100%[===================>]  72.59M   169MB/s    in 0.4s
#
# 2023-05-08 22:37:44 (169 MB/s) - ‘Miniconda3-py38_4.12.0-Linux-x86_64.sh’ saved [76120962/76120962]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - _openmp_mutex==4.5=1_gnu
#     - brotlipy==0.7.0=py38h27cfd23_1003
#     - ca-certificates==2022.3.29=h06a4308_1
#     - certifi==2021.10.8=py38h06a4308_2
# ...

# %%
import sys
sys.path.append('/usr/local/lib/python3.8/site-packages')

# %%
# Mount Google Drive
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !conda env create -f gdrive/My\ Drive/CounterGEDI/environment_droplet.yml
# Out:
# done
# failed
#
# ResolvePackageNotFound:
#   - certifi==2022.12.7=py38haa95532_0
#   - pycodestyle==2.10.0=py38haa95532_0
#   - debugpy==1.5.1=py38hd77b12b_0
#   - openssl==1.1.1t=h2bbff1b_0
#   - pywin32==305=py38h2bbff1b_0
#   - wheel==0.38.4=py38haa95532_0
#   - setuptools==65.6.3=py38haa95532_0
#   - wincertstore==0.2=py38haa95532_2
#   - vc==14.2=h21ff451_1
#   - python==3.8.16=h6244533_3
#   - jupyter_core==5.3.0=py38haa244fe_0
#   - sqlite==3.41.1=h2bbff1b_0
#   - pyzmq==23.2.0=py38hd77b12b_0
#   - libffi==3.4.2=hd77b12b_6
#   - ca-certificates==2023.01.10=haa95532_0
#   - tornado==6.2=py38h294d835_0
#   - libsodium==1.0.18=h8d14728_1
#   - vs2015_runtime==14.27.29016=h5e58377_2
#   - pip==23.0.1=py38haa95532_0
#   - zeromq==4.3.4=h0e60522_1

# %%
# !nvidia-smi
# Out:
# Mon May  8 22:19:48 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# Install Libraries
# %%capture
# !pip install tensorflow 
# !pip install torch
# !pip install torchvision 
# !pip install torchaudio

# !pip install dataclasses
# !pip install ekphrasis
# !pip install Keras
# !pip install activations
# !pip install file_utils
# !pip install GPUtil
# !pip install scikit_learn
# !pip install Keras-Preprocessing
# !pip install neptune-client==0.14.2
# !pip install pytorch_pretrained_bert
# !pip install transformers
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
# Install Libraries
#%%capture
# !pip install numpy
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
# wrap outputs cells
from IPython.display import HTML, display

def set_css():
  display(HTML('''
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  '''))
get_ipython().events.register('pre_run_cell', set_css)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
import os
import torch
import pandas as pd
import sys
import glob

# set device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
# set path
root_dir = "gdrive/My Drive/CounterGEDI/"

sys.path.append(os.path.join("/content/", root_dir))
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
#%%capture
# !python gdrive/My\ Drive/CounterGEDI/GEDI_training.py
#!python gdrive/My\ Drive/CounterGEDI/Discriminator_training.py
# !python gdrive/My\ Drive/CounterGEDI/Generation_gedi.py
# !python gdrive/My\ Drive/CounterGEDI/Generation_training.py
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Traceback (most recent call last):
#   File "/content/gdrive/My Drive/CounterGEDI/GEDI_training.py", line 2, in <module>
#     from Discriminator.models import *
#   File "/content/gdrive/My Drive/CounterGEDI/Discriminator/models.py", line 1, in <module>
#     import torch
# ModuleNotFoundError: No module named 'torch'
